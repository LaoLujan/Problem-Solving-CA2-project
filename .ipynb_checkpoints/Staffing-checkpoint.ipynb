# %% [markdown]
# SATFFING PROJECT
# The main purpose of this project is to predict the staff needed to work in an hotel in Glasneeving area, this predictions are going to be based on historical Weather, events and ocupancy from the hotel. This predictions will impact to prevent overstaffing and understafing, generating a better distribution of staff, improving customer service and avoiding the waste on salaries.

# %% [markdown]
# WEATHER DATA SET
# In this section I imported 3 data sets from MEt Eireann, from 2023, 2024 and 2025, It contains information like rain, max temperature, min temprerature and date, those 4 are the features I need to determin "How a good weather look like". I merged the 3 data sets and I defined this 3 parameters, 1 Good/Warm, 2 Dry/Cool, 3 Poor/Wet.

# %%
#Important libraries 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Import the 3 data sets from Met Eireann, the sets are clean and organized, the main task here is to merge them and create the conditionals that
#will determine how a good weather looks like to impact the hotel ocupancy
df_23 = pd.read_csv("DataSets/dly1823_subset 2023.csv", skiprows=13)
df_24 = pd.read_csv("DataSets/dly1823_subset2024.csv", skiprows=13 )
df_25 = pd.read_csv("DataSets/dly1823_subset 2025.csv", skiprows=13)

#Combine into one master weather dataframe, 
df = pd.concat([df_23, df_24, df_25], ignore_index=True)


# Preview the data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1065 entries, 0 to 1064
# Data columns (total 9 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    1065 non-null   object
#  1   ind     1065 non-null   int64
#  2   rain    1065 non-null   float64
#  3   ind.1   1065 non-null   int64
#  4   maxt    1065 non-null   float64
#  5   ind.2   1065 non-null   int64
#  6   mint    1065 non-null   float64
#  7   gmin    1065 non-null   object
#  8   soil    1065 non-null   object
# dtypes: float64(3), int64(3), object(3)
# memory usage: 75.0+ KB

# %%
df.head
# Out:
# <bound method NDFrame.head of              date  ind  rain  ind.1  maxt  ind.2  mint  gmin soil
# 0        1-Jan-23    0   0.4      0   7.2      0   2.5   1.4
# 1        2-Jan-23    0   0.8      0  10.9      0   1.9  -1.7
# 2        3-Jan-23    0   0.6      0  14.4      1  -0.5  -4.4
# 3        4-Jan-23    0   0.2      0  12.9      0   9.4   8.2
# 4        5-Jan-23    0   1.8      0  13.7      0   9.6   6.4
# ...           ...  ...   ...    ...   ...    ...   ...   ...  ...
# 1060  26-nov-2025    0   0.8      0  14.6      1  -1.0  -4.5
# 1061  27-nov-2025    0   7.7      0  16.0      0   8.8   3.0
# 1062  28-nov-2025    0   1.7      0   9.2      0   6.5   3.2
# 1063  29-nov-2025    0   4.1      0   6.9      0   2.3  -3.9
# 1064  30-nov-2025    0   9.2      0  12.4      0   0.2  -5.0
#
# [1065 rows x 9 columns]>

# %%
df_filtered = df [["date", "rain", "maxt", "mint"]] #Now I'll filter only the freatures that impact my model.
df_filtered.head()
# Out:
#        date  rain  maxt  mint
# 0  1-Jan-23   0.4   7.2   2.5
# 1  2-Jan-23   0.8  10.9   1.9
# 2  3-Jan-23   0.6  14.4  -0.5
# 3  4-Jan-23   0.2  12.9   9.4
# 4  5-Jan-23   1.8  13.7   9.6

# %%
df_filtered = df[["date", "rain", "maxt", "mint"]].copy()
conditions = [
    #Good/Warm: Less than 1mm rain AND 16C or warmer
    (df_filtered["rain"] < 1.0) & (df_filtered["maxt"] >= 13),
    
    #Dry/Cool: Less than 1mm rain AND cooler than 16C
    (df_filtered["rain"] < 1.0) & (df_filtered["maxt"] < 13),
    
    #Poor/Wet: 5mm+ of rain OR very cold (under 5C max)
    (df_filtered["rain"] >= 5.0) | (df_filtered["maxt"] < 8),
]

choices = ["Good/Warm", "Dry/Cool", "Poor/Wet"]

# Apply the choices, everything else becomes 'Moderate/Changeable'
df_filtered["weather_quality"] = np.select(conditions, choices, default="Moderate/Changeable")


df_filtered.head(10)
# Out:
#         date  rain  maxt  mint      weather_quality
# 0   1-Jan-23   0.4   7.2   2.5             Dry/Cool
# 1   2-Jan-23   0.8  10.9   1.9             Dry/Cool
# 2   3-Jan-23   0.6  14.4  -0.5            Good/Warm
# 3   4-Jan-23   0.2  12.9   9.4             Dry/Cool
# 4   5-Jan-23   1.8  13.7   9.6  Moderate/Changeable
# 5   6-Jan-23   3.1  12.3   6.9  Moderate/Changeable
# 6   7-Jan-23   0.8  10.7   7.6             Dry/Cool
# 7   8-Jan-23   0.9   8.4   6.6             Dry/Cool
# 8   9-Jan-23   5.5  13.3   4.4             Poor/Wet
# 9  10-Jan-23   3.5  14.1   5.0  Moderate/Changeable

# %% [markdown]
# DUBLIN EVENTS DATA SET
# This data set was created with the help of AI to find all the past events from 2023 to 2025 that can impact the Glasneevin area. This data set will help to predict the events that can impact the hotel occupancy.
# I specifically created the list of events with the "date" column in the same format than wetaher data set, so I can merge them together.

# %%
df_events = pd.read_csv("DataSets/dublin_events_2023_2025.csv")
df_events.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34 entries, 0 to 33
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   date          34 non-null     object
#  1   event_impact  34 non-null     int64
#  2   event_name    34 non-null     object
# dtypes: int64(1), object(2)
# memory usage: 948.0+ bytes

# %%
df_events.head(10) #first overview of the data set
# Out:
#         date  event_impact                                         event_name
# 0  11-Feb-23             1                     Six Nations: Ireland vs France
# 1  17-Mar-23             2                         St. Patrick's Day Festival
# 2  18-Mar-23             1                    Six Nations: Ireland vs England
# 3   5-May-23             2                          Bruce Springsteen Concert
# 4   7-May-23             2                          Bruce Springsteen Concert
# 5   9-May-23             2                          Bruce Springsteen Concert
# 6  20-May-23             1               Heineken Champions Cup Final (Aviva)
# 7  23-Jul-23             2      All-Ireland Senior Hurling Final (Croke Park)
# 8  30-Jul-23             2     All-Ireland Senior Football Final (Croke Park)
# 9  26-Aug-23             1  College Football Classic: Notre Dame vs Navy (...

# %%
df_filtered["date"] = pd.to_datetime(df_filtered["date"], format="mixed", dayfirst="TRUE") # I can see all the rows share the same date format so now I can merge based on that
df_events["date"] = pd.to_datetime(df_events["date"], format="mixed", dayfirst="TRUE")
df_merged = pd.merge(df_filtered, df_events, on= "date", how="left")

# %%
df_merged["event_impact"] = df_merged["event_impact"].fillna(0) # on the df the days that we dont have events should be marked as 0
df_merged["event_name"] = df_merged["event_name"].fillna("No Event") # and the name as No event, insted of just saying NAN
df_merged.head()
#Event impact 0 means no event, and 1 means we have an event that can impact the bussiness
# Out:
#         date  rain  maxt  mint      weather_quality  event_impact event_name
# 0 2023-01-01   0.4   7.2   2.5             Dry/Cool           0.0   No Event
# 1 2023-01-02   0.8  10.9   1.9             Dry/Cool           0.0   No Event
# 2 2023-01-03   0.6  14.4  -0.5            Good/Warm           0.0   No Event
# 3 2023-01-04   0.2  12.9   9.4             Dry/Cool           0.0   No Event
# 4 2023-01-05   1.8  13.7   9.6  Moderate/Changeable           0.0   No Event

# %% [markdown]
# THE HOTEL DATA SET
# This data set contains a data set obtained from Kaggle, based on the first overview I can see that the data corresponds to a different year that I am not focus on, so since this is not a real data set, instead of finding one that belongs to 2023, 2024, and 2025, I'll modify the years to match my events and weather data sets.
# This data set contains many columns that are not align with my other data sets so I'll unify them to try to match dates.

# %%
df_hotel = pd.read_csv("DataSets/hotel_bookings.csv")
df_hotel.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
#  12  meal                            119390 non-null  object
#  13  country                         118902 non-null  object
#  14  market_segment                  119390 non-null  object
#  15  distribution_channel            119390 non-null  object
#  16  is_repeated_guest               119390 non-null  int64
#  17  previous_cancellations          119390 non-null  int64
#  18  previous_bookings_not_canceled  119390 non-null  int64
#  19  reserved_room_type              119390 non-null  object
#  20  assigned_room_type              119390 non-null  object
#  21  booking_changes                 119390 non-null  int64
#  22  deposit_type                    119390 non-null  object
#  23  agent                           103050 non-null  float64
#  24  company                         6797 non-null    float64
#  25  days_in_waiting_list            119390 non-null  int64
#  26  customer_type                   119390 non-null  object
#  27  adr                             119390 non-null  float64
#  28  required_car_parking_spaces     119390 non-null  int64
#  29  total_of_special_requests       119390 non-null  int64
#  30  reservation_status              119390 non-null  object
#  31  reservation_status_date         119390 non-null  object
# dtypes: float64(4), int64(16), object(12)
# memory usage: 29.1+ MB

# %%
df_hotel.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  deposit_type  \
# 0                        0                     0       2  ...    No Deposit
# 1                        0                     0       2  ...    No Deposit
# 2                        0                     1       1  ...    No Deposit
# 3                        0                     1       1  ...    No Deposit
# 4                        0                     2       2  ...    No Deposit
#
#    agent company days_in_waiting_list customer_type   adr  \
# 0    NaN     NaN                    0     Transient   0.0
# 1    NaN     NaN                    0     Transient   0.0
# 2    NaN     NaN                    0     Transient  75.0
# 3  304.0     NaN                    0     Transient  75.0
# 4  240.0     NaN                    0     Transient  98.0
#
#    required_car_parking_spaces  total_of_special_requests  reservation_status  \
# 0                            0                          0           Check-Out
# 1                            0                          0           Check-Out
# 2                            0                          0           Check-Out
# 3                            0                          0           Check-Out
# 4                            0                          1           Check-Out
#
#   reservation_status_date
# 0              2015-07-01
# 1              2015-07-01
# 2              2015-07-02
# 3              2015-07-02
# 4              2015-07-03
#
# [5 rows x 32 columns]

# %%
df_hotel_clean = df_hotel.copy() #I create a copy so I don't mess up the original

# Manually replace each year one by one, this data set do not contain real information and do not belong to the time/years I an trying to use for my machine
#learning, so I changed the years to 2023,2024 and 2025 to match my event and weather data sets.  
df_hotel_clean["arrival_date_year"] = df_hotel_clean["arrival_date_year"].replace(2015, 2023)
df_hotel_clean["arrival_date_year"] = df_hotel_clean["arrival_date_year"].replace(2016, 2024)
df_hotel_clean["arrival_date_year"] = df_hotel_clean["arrival_date_year"].replace(2017, 2025)

# Show the first few rows to prove it worked
df_hotel_clean[["hotel", "arrival_date_year"]].head(10)
# Out:
#           hotel  arrival_date_year
# 0  Resort Hotel               2023
# 1  Resort Hotel               2023
# 2  Resort Hotel               2023
# 3  Resort Hotel               2023
# 4  Resort Hotel               2023
# 5  Resort Hotel               2023
# 6  Resort Hotel               2023
# 7  Resort Hotel               2023
# 8  Resort Hotel               2023
# 9  Resort Hotel               2023

# %%
print("Hotels found in data:", df_hotel_clean["hotel"].unique()) #I can see the set contain more than one hotel, I'll get rid onf one
# Out:
# Hotels found in data: ['Resort Hotel' 'City Hotel']

# %%
df_single_hotel = df_hotel_clean[df_hotel["hotel"] == "City Hotel"].copy() # I choose to stay with City Hotel

# %%
print("Hotels found in data:", df_single_hotel["hotel"].unique()) # Now I can confirm I only have one hotel to analyse
# Out:
# Hotels found in data: ['City Hotel']

# %%
 print(df_single_hotel["arrival_date_year"].unique()) #And I just confirm I have data on the years I need
# Out:
# [2023 2024 2025]

# %%
#By looking at the columns I can see that the information I need is in "adults", I only focus on how many people stayed per nigth and I'll include "kids" too
df_single_hotel["total_people"] = df_single_hotel["adults"] + df_single_hotel["children"].fillna(0)

# %%
#I mapped the months, since on the data set they have different formatting, I have to reset the dates to make them fit with my other sets
month_map= {"January":1, "February":2, "March":3, "April":4, "May":5, "June":6, 
             "July":7, "August":8, "September":9, "October":10, "November":11, "December":12}
df_single_hotel["month_num"] = df_single_hotel["arrival_date_month"].map(month_map)

# %%
df_single_hotel['date'] = pd.to_datetime({ # now combine year, month and day in to my df
    "year": df_single_hotel["arrival_date_year"],
    "month": df_single_hotel["month_num"],
    "day": df_single_hotel["arrival_date_day_of_month"]
})

# %%
df_occupancy = df_single_hotel.groupby("date")["total_people"].sum().reset_index()

df_occupancy.rename(columns={"total_people": "occupancy"}, inplace=True) #I renamed the column to make it clear 
df_occupancy["occupancy"] = df_occupancy["occupancy"].fillna(0)
df_occupancy.head(10)
# Out:
#         date  occupancy
# 0 2023-07-01      143.0
# 1 2023-07-02       96.0
# 2 2023-07-03       28.0
# 3 2023-07-04       72.0
# 4 2023-07-05       15.0
# 5 2023-07-06       58.0
# 6 2023-07-07       35.0
# 7 2023-07-08       79.0
# 8 2023-07-09       92.0
# 9 2023-07-10       19.0

# %% [markdown]
# FINAL MERGE : So at this point I have 3 data sets, df_occupancy from the hotel, df_merged that contains weather and events data sets, its time to create a mega final merge to combine all the information we need to start our analysis;
# I identified a missmatch on the starting dates, the data set from Met Eireann starts from January whereas the data set fromt the hotel occupancy starts from July. To ensure the Random Forest model is trained with the best quality, I removed the initial 6 months where the occupancy was missing.

# %%
df_final = pd.merge(df_merged, df_occupancy, on= "date", how="left") #Final merge of data sets

# %%
print("3 Data sets integrated: ", df_final.columns.tolist()) #
# Turn the NaNs into 0.0
df_final["occupancy"] = df_final["occupancy"].fillna(0)
df_final.head(5)
# Out:
# 3 Data sets integrated:  ['date', 'rain', 'maxt', 'mint', 'weather_quality', 'event_impact', 'event_name', 'occupancy', 'day_of_week']
#         date  rain  maxt  mint      weather_quality  event_impact event_name  \
# 0 2023-07-01   0.0  19.4  13.3            Good/Warm           0.0   No Event
# 1 2023-07-02   3.2  18.1  11.2  Moderate/Changeable           0.0   No Event
# 2 2023-07-03   6.4  18.1  10.6             Poor/Wet           0.0   No Event
# 3 2023-07-04   2.5  20.2  10.2  Moderate/Changeable           0.0   No Event
# 4 2023-07-05   0.0  18.7   9.9            Good/Warm           0.0   No Event
#
#    occupancy day_of_week
# 0      143.0   Wednesday
# 1       96.0    Thursday
# 2       28.0      Friday
# 3       72.0    Saturday
# 4       15.0      Sunday

# %%
#I notticed the occupancy is 0 for way too many rows, now I can validate the data sets do not match
#they have different starting points, the best way to address this can be delete the firs 6 months of the 
#df_merged 
print("weather and events data set", df_merged["date"].min())
print("weather and events data set", df_merged["date"].max())
print("Hotel data set", df_occupancy["date"].min())
print("Hotel data set", df_occupancy["date"].max())
# Out:
# weather and events data set 2023-01-01 00:00:00
# weather and events data set 2025-11-30 00:00:00
# Hotel data set 2023-07-01 00:00:00
# Hotel data set 2025-08-31 00:00:00

# %%
df_final = df_final[df_final["date"].between ("2023-07-01", "2025-08-31")].copy() #Again I created a copy to protect the previous data, and I choose
#to select the data only on the dates that actually matches weather data set AND occupancy hotel.
df_final = df_final.reset_index(drop=True) # Reset the index so the first row in July is Row 0

print("Final data set starting date", df_final["date"].min())
print("Final data set end date", df_final["date"].max())
# Out:
# Final data set starting date 2023-07-01 00:00:00
# Final data set end date 2025-08-31 00:00:00

# %%
df_final.head(5)
# Out:
#         date  rain  maxt  mint      weather_quality  event_impact event_name  \
# 0 2023-07-01   0.0  19.4  13.3            Good/Warm           0.0   No Event
# 1 2023-07-02   3.2  18.1  11.2  Moderate/Changeable           0.0   No Event
# 2 2023-07-03   6.4  18.1  10.6             Poor/Wet           0.0   No Event
# 3 2023-07-04   2.5  20.2  10.2  Moderate/Changeable           0.0   No Event
# 4 2023-07-05   0.0  18.7   9.9            Good/Warm           0.0   No Event
#
#    occupancy day_of_week
# 0      143.0   Wednesday
# 1       96.0    Thursday
# 2       28.0      Friday
# 3       72.0    Saturday
# 4       15.0      Sunday

# %% [markdown]
# EDA ANALYSIS:
#
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!WHEN YOU FINSH WRITE HERE FINAL RESULTS AND GENERAL INFO ABOUT ALL THE PLOTS !!!!!!!!!!!!!!!1

# %% [markdown]
# PLOT 1: Gave me an idea of how noisy the data can look like, but it gave me some valuable overview, like again one of my datasets was empty for 6 months at the end of 2025, so I went back to delete some rows like I did before, so now we have valuable information for our model from beggining to end.
# This first stage of EDA will be dedicated to identify patterns on seasonal occupancy, and find out on detail where those spikes belong to.

# %%
#PLOT 1
plt.figure(figsize=(15, 6))
sns.lineplot(data=df_final, x="date", y="occupancy")
plt.title("Daily Hotel Occupancy July 2023 - August 2025")
plt.xlabel("Date")
plt.ylabel("Occupancy")
plt.grid(True, alpha=0.3)
plt.show()

# %% [markdown]
# PLOT 2: The staffing levels can be seen per day, this shows in average how many guests do we have per day and which days the staff is more busy, this  indicates that the days of the week are a stong predictor. While the days are a bit volatile, when aggregated, they reveals a clear pick demand on Thurday, Friday, Saturday and Monday.

# %%
#PLOT 2
df_final["day_of_week"] = df_final["date"].dt.day_name() #dt.day_time calls the days of the week from 2015, 2016 and 2017, BUT I modified the dataset en .replace() for 2023,2024 and 2025
day_correction_map= {"Monday":"Friday", "Tuesday":"Saturday", "Wednesday":"Sunday", "Thursday":"Monday", "Friday":"Tuesday", "Saturday":"Wednesday", 
             "Sunday":"Thursday"}
df_final["day_of_week"]=df_final["day_of_week"].replace(day_correction_map) #I created a map where I can correct the days of the week. In the same way I replaced the years
#now I have to replace the days of the week according to the new years.
#Before this day of the week replacement, the plot showed the bussiest day for the hotel was on Mondays, which seems
#unusual, so now with the new map, the days match according to the year and make sense for an hotel.

# %%
days_order = ["Monday", "Tuesday", "Wednesday", "Thursday", "Friday", "Saturday", "Sunday"] #I organise the days according to the week
df_final["day_of_week"] = pd.Categorical(df_final["day_of_week"], categories=days_order, ordered=True)

# %%
plt.figure(figsize=(12, 6))
ax = sns.barplot(data=df_final, x="day_of_week", y="occupancy") # Calculate the average guests for each day
ax.bar_label(ax.containers[0], fmt="%.0f")

plt.title("Average Hotel Occupancy by Day of the Week")
plt.ylabel("Average Guests")
plt.xlabel("Day")
plt.grid(True, alpha=0.3)
plt.show()

# %% [markdown]
# PLOT 3
# This box plot have a huge aportation to this project, it indicates that on days where there is No event (0.0), the hotel had high occupancy, could be probably the good weather or a bank holiday, but also means that is hard to predict how many guest we could have in a normal day since the information looks spread, going from a minimum of probably 10 guests to 470, and the outliners indicates even more  than 600 guests.
# It shows that on days where big events are present (2.0), the occupancy increase, proving that definetely the media of occupancy is arround 240, probably 50 more than a normal day, although, the days with small events (1.0), the occupancy is not really afected, is showing less impact that I expected.

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(data=df_final, x="event_impact", y="occupancy")
plt.title("Occupancy Distribution: Normal Days vs Event Days")
plt.grid(True, alpha=0.3)
plt.show()

# %% [markdown]
# PLOT 4

# %%
month_names = {1: "Jan", 2: "Feb", 3: "Mar", 4: "Apr", 5: "May", 6: "Jun", 
               7: "Jul", 8: "Aug", 9: "Sep", 10: "Oct", 11: "Nov", 12: "Dec"} #The map I did before doesnt work visually for this plot so I mapped another one here

df_final["month_name"] = df_final["month_num"].map(month_names)
month_order = ["Jan", "Feb", "Mar", "Apr", "May", "Jun", "Jul", "Aug", "Sep", "Oct", "Nov", "Dec"] # I ordered them so they dont appear alphabetically
df_final["month_name"] = pd.Categorical(df_final["month_name"], categories=month_order, ordered=True)

# Create the Line Plot
plt.figure(figsize=(12, 6))
sns.lineplot(data=df_final, x="month_name", y="occupancy", marker="o",)
plt.title("Average Monthly Occupancy")
plt.ylabel("Average Guests")
plt.xlabel("Month")
plt.grid(True, alpha=0.3)
plt.show()

# %%
PEDIENTE ANALIZAR ESTE ULTIMO PLOT, ESCRIBE LA INTERPRETACION
